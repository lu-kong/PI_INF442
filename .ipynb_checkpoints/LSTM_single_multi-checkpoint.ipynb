# %%
from util import *
import numpy as np
from matplotlib import pyplot as plt

from util_cleaning import *
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler



from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
import numpy as np
import tensorflow as tf

# %%
features = pd.read_csv(DATABASE_PATH + 'cleaned_data/final_3h.csv',';')
features
# Out:
#                 full_time  power_consummption  temperature  humidity  \
# 0     2007-01-01 00:00:00            2.552122       286.65      89.0
# 1     2007-01-01 03:00:00            2.497878       285.65      80.0
# 2     2007-01-01 06:00:00            2.448244       283.65      77.0
# 3     2007-01-01 09:00:00            2.794622       282.05      76.0
# 4     2007-01-01 12:00:00            2.024222       283.65      62.0
# ...                   ...                 ...          ...       ...
# 8746  2009-12-31 09:00:00            1.852422       280.35      93.0
# 8747  2009-12-31 12:00:00            1.644028       279.95      93.0
# 8748  2009-12-31 15:00:00            1.582144       277.15      94.0
# 8749  2009-12-31 18:00:00            2.948644       275.45      96.0
# 8750  2009-12-31 21:00:00            2.200078       274.25      95.0
#
#       visibility  nebulosity
# 0        20000.0         2.0
# 1        20000.0         2.0
# 2        20000.0         2.0
# 3        17000.0         2.0
# 4        25000.0         1.0
# ...          ...         ...
# 8746     16000.0         5.0
# 8747      8000.0         4.0
# 8748      5000.0         4.0
# 8749      3000.0         4.0
# 8750      4000.0         4.0
#
# [8751 rows x 6 columns]

# %% [markdown]
# # data_set processes

# %%
features.plot(subplots=True,figsize = (12,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019D0FDE2F88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019D1014EF48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019D1018C488>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019D101C0E88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019D101F9908>],
#       dtype=object)

# %%
TRAIN_SPLIT = int(features.shape[0]*0.7)
past_history = 30
future_target = 1
STEP = 1
BATCH_SIZE = 256
BUFFER_SIZE = 10000
EVALUATION_INTERVAL = 200
EPOCHS = 30

# %%
dataset = features.iloc[:,1:].values.astype('float')
# dataset = dataset.astype('float'
#                     )
dataset
# Out:
# array([[2.55212222e+00, 2.86650000e+02, 8.90000000e+01, 2.00000000e+04,
#         2.00000000e+00],
#        [2.49787778e+00, 2.85650000e+02, 8.00000000e+01, 2.00000000e+04,
#         2.00000000e+00],
#        [2.44824444e+00, 2.83650000e+02, 7.70000000e+01, 2.00000000e+04,
#         2.00000000e+00],
#        ...,
#        [1.58214444e+00, 2.77150000e+02, 9.40000000e+01, 5.00000000e+03,
#         4.00000000e+00],
#        [2.94864444e+00, 2.75450000e+02, 9.60000000e+01, 3.00000000e+03,
#         4.00000000e+00],
#        [2.20007778e+00, 2.74250000e+02, 9.50000000e+01, 4.00000000e+03,
#         4.00000000e+00]])

# %%
# dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)

# %%
dataset = (dataset-data_mean)/data_std

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 0], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 0],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (30, 5)

# %%
BATCH_SIZE = 256
BUFFER_SIZE = 10000
EVALUATION_INTERVAL = 200
EPOCHS = 30

# %%
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %% [markdown]
# # Single step model

# %%
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(64,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(32,activation = 'relu'))
single_step_model.add(tf.keras.layers.Dense(1))
single_step_model.add(tf.keras.layers.Dropout(0.2))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

# %%
for x, y in val_data_single.take(1):
    print(single_step_model.predict(x).shape)
# Out:
# (256, 1)

# %%
single_step_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 64)                17920
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1)                 0
# =================================================================
# Total params: 20,033
# Trainable params: 20,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/30
# 200/200 [==============================] - 18s 88ms/step - loss: 0.7544 - val_loss: 0.6406
# Epoch 2/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.6977 - val_loss: 0.5962
# Epoch 3/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.6530 - val_loss: 0.5382
# Epoch 4/30
# 200/200 [==============================] - 12s 60ms/step - loss: 0.6252 - val_loss: 0.5427
# Epoch 5/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.6041 - val_loss: 0.5262
# Epoch 6/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5898 - val_loss: 0.5324
# Epoch 7/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5756 - val_loss: 0.5346
# Epoch 8/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5581 - val_loss: 0.5410
# Epoch 9/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5429 - val_loss: 0.5516
# Epoch 10/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5247 - val_loss: 0.5545
# Epoch 11/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5106 - val_loss: 0.5563
# Epoch 12/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.4957 - val_loss: 0.5706
# Epoch 13/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.4827 - val_loss: 0.5650
# Epoch 14/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.4689 - val_loss: 0.5703
# Epoch 15/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.4569 - val_loss: 0.5814
# Epoch 16/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.4445 - val_loss: 0.5756
# Epoch 17/30
# 200/200 [==============================] - 12s 60ms/step - loss: 0.4347 - val_loss: 0.5765
# Epoch 18/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.4252 - val_loss: 0.5814
# Epoch 19/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.4162 - val_loss: 0.5869
# Epoch 20/30
# 200/200 [==============================] - 12s 60ms/step - loss: 0.4075 - val_loss: 0.5894
# Epoch 21/30
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3976 - val_loss: 0.5974
# Epoch 22/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3916 - val_loss: 0.5956
# Epoch 23/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3868 - val_loss: 0.5917
# Epoch 24/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.3820 - val_loss: 0.5979
# Epoch 25/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3707 - val_loss: 0.6031
# Epoch 26/30
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3637 - val_loss: 0.6029
# Epoch 27/30
# 200/200 [==============================] - 12s 58ms/step - loss: 0.3610 - val_loss: 0.6117
# Epoch 28/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3544 - val_loss: 0.6083
# Epoch 29/30
# 200/200 [==============================] - 11s 57ms/step - loss: 0.3475 - val_loss: 0.6156
# Epoch 30/30
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3453 - val_loss: 0.6093

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()

    plt.show()

# %%
plot_train_history(single_step_history,
                   'Single Step Training and validation loss')

# %%
def show_plot(plot_data, delta, title):
    labels = ['History', 'True Future', 'Model Prediction']
    marker = ['.-', 'rx', 'go']
    time_steps = create_time_steps(plot_data[0].shape[0])
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, x in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10,
                   label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future+5)*2])
    plt.xlabel('Time-Step')
    return plt

# %%
def create_time_steps(length):
    return list(range(-length, 0))

# %%
for x, y in val_data_single.take(5):
    plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 5
                     ,
                   'Single Step Prediction')
    plot.show()

# %%
x_train_single.shape
# Out:
# (6095, 30, 5)

# %% [markdown]
# # Multi step model

# %%
future_target = 36
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 0], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 0],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

# %%
print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (60, 5)
#
#  Target temperature to predict : (36,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
    plt.figure(figsize=(12, 6))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)

    plt.plot(num_in, np.array(history[:, 1]), label='History')
    plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'b',
           label='True Future')
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'r',
             label='Predicted Future')
    plt.legend(loc='upper left')
    plt.show()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(36))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

# %%
for x, y in val_data_multi.take(1):
    print (multi_step_model.predict(x).shape)
# Out:
# (256, 36)

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/30
# 200/200 [==============================] - 29s 143ms/step - loss: 0.8023 - val_loss: 0.7021
# Epoch 2/30
# 200/200 [==============================] - 21s 107ms/step - loss: 0.7746 - val_loss: 0.7052
# Epoch 3/30
# 200/200 [==============================] - 21s 105ms/step - loss: 0.7614 - val_loss: 0.7057
# Epoch 4/30
# 200/200 [==============================] - 21s 104ms/step - loss: 0.7511 - val_loss: 0.7132
# Epoch 5/30
# 200/200 [==============================] - 21s 105ms/step - loss: 0.7397 - val_loss: 0.7263
# Epoch 6/30
# 200/200 [==============================] - 21s 105ms/step - loss: 0.7302 - val_loss: 0.7254
# Epoch 7/30
# 200/200 [==============================] - 21s 104ms/step - loss: 0.7219 - val_loss: 0.7277
# Epoch 8/30
# 200/200 [==============================] - 21s 105ms/step - loss: 0.7144 - val_loss: 0.7301
# Epoch 9/30
# 200/200 [==============================] - 20s 102ms/step - loss: 0.7074 - val_loss: 0.7324
# Epoch 10/30
# 200/200 [==============================] - 22s 111ms/step - loss: 0.7012 - val_loss: 0.7297
# Epoch 11/30
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6952 - val_loss: 0.7405
# Epoch 12/30
# 200/200 [==============================] - 20s 102ms/step - loss: 0.6889 - val_loss: 0.7367 - loss: 0
# Epoch 13/30
# 200/200 [==============================] - 20s 102ms/step - loss: 0.6826 - val_loss: 0.7316
# Epoch 14/30
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6761 - val_loss: 0.7292
# Epoch 15/30
# 200/200 [==============================] - 21s 103ms/step - loss: 0.6643 - val_loss: 0.7159
# Epoch 16/30
# 200/200 [==============================] - 20s 102ms/step - loss: 0.6480 - val_loss: 0.7216
# Epoch 17/30
# 200/200 [==============================] - 20s 102ms/step - loss: 0.6348 - val_loss: 0.7143
# Epoch 18/30
# 200/200 [==============================] - 22s 110ms/step - loss: 0.6237 - val_loss: 0.7040
# Epoch 19/30
# 200/200 [==============================] - 20s 102ms/step - loss: 0.6111 - val_loss: 0.6936
# Epoch 20/30
# 200/200 [==============================] - 21s 104ms/step - loss: 0.5926 - val_loss: 0.6770
# Epoch 21/30
# 200/200 [==============================] - 21s 104ms/step - loss: 0.5709 - val_loss: 0.6535
# Epoch 22/30
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5560 - val_loss: 0.6474
# Epoch 23/30
# 200/200 [==============================] - 20s 101ms/step - loss: 0.5468 - val_loss: 0.6497
# Epoch 24/30
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5406 - val_loss: 0.6489
# Epoch 25/30
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5349 - val_loss: 0.6415
# Epoch 26/30
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5311 - val_loss: 0.6493
# Epoch 27/30
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5267 - val_loss: 0.6376
# Epoch 28/30
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5236 - val_loss: 0.6474
# Epoch 29/30
# 200/200 [==============================] - 21s 104ms/step - loss: 0.5205 - val_loss: 0.6573
# Epoch 30/30
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5183 - val_loss: 0.6418

# %%
for x, y in val_data_multi.take(3):
    multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])

# %%
multi_step_history_200 = multi_step_model.fit(train_data_multi, epochs=200,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.5158 - val_loss: 0.6580
# Epoch 2/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5136 - val_loss: 0.6558
# Epoch 3/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.5116 - val_loss: 0.6529
# Epoch 4/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.5098 - val_loss: 0.6510
# Epoch 5/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.5080 - val_loss: 0.6670
# Epoch 6/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.5063 - val_loss: 0.6562
# Epoch 7/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5047 - val_loss: 0.6521
# Epoch 8/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.5033 - val_loss: 0.6493
# Epoch 9/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.5016 - val_loss: 0.6502
# Epoch 10/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.5000 - val_loss: 0.6603
# Epoch 11/200
# 200/200 [==============================] - 20s 99ms/step - loss: 0.4986 - val_loss: 0.6514
# Epoch 12/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4977 - val_loss: 0.6597
# Epoch 13/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4964 - val_loss: 0.6663
# Epoch 14/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4952 - val_loss: 0.6638
# Epoch 15/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4940 - val_loss: 0.6665
# Epoch 16/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4931 - val_loss: 0.6618
# Epoch 17/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4917 - val_loss: 0.6586
# Epoch 18/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4911 - val_loss: 0.6608
# Epoch 19/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4899 - val_loss: 0.6675
# Epoch 20/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4890 - val_loss: 0.6668
# Epoch 21/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4881 - val_loss: 0.6691
# Epoch 22/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4873 - val_loss: 0.6616
# Epoch 23/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4862 - val_loss: 0.6673
# Epoch 24/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4854 - val_loss: 0.6701
# Epoch 25/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4845 - val_loss: 0.6623
# Epoch 26/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4838 - val_loss: 0.6616
# Epoch 27/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4831 - val_loss: 0.6587
# Epoch 28/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4823 - val_loss: 0.6668
# Epoch 29/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4814 - val_loss: 0.6748
# Epoch 30/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4809 - val_loss: 0.6612
# Epoch 31/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4800 - val_loss: 0.6619
# Epoch 32/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4793 - val_loss: 0.6659
# Epoch 33/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4788 - val_loss: 0.6664
# Epoch 34/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4779 - val_loss: 0.6595
# Epoch 35/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4775 - val_loss: 0.6623
# Epoch 36/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4766 - val_loss: 0.6680
# Epoch 37/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4757 - val_loss: 0.6651
# Epoch 38/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4754 - val_loss: 0.6635
# Epoch 39/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4747 - val_loss: 0.6592
# Epoch 40/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4741 - val_loss: 0.6663
# Epoch 41/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4732 - val_loss: 0.6660
# Epoch 42/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4729 - val_loss: 0.6671
# Epoch 43/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4720 - val_loss: 0.6701
# Epoch 44/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4715 - val_loss: 0.6673
# Epoch 45/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4710 - val_loss: 0.6697
# Epoch 46/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4703 - val_loss: 0.6717
# Epoch 47/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4694 - val_loss: 0.6719
# Epoch 48/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4693 - val_loss: 0.6757
# Epoch 49/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4686 - val_loss: 0.6757
# Epoch 50/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4679 - val_loss: 0.6709
# Epoch 51/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4676 - val_loss: 0.6753
# Epoch 52/200
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4668 - val_loss: 0.6690
# Epoch 53/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4663 - val_loss: 0.6767
# Epoch 54/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4662 - val_loss: 0.6789
# Epoch 55/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4651 - val_loss: 0.6747
# Epoch 56/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4646 - val_loss: 0.6814
# Epoch 57/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4644 - val_loss: 0.6799
# Epoch 58/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4635 - val_loss: 0.6859
# Epoch 59/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4632 - val_loss: 0.6750
# Epoch 60/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4626 - val_loss: 0.6746
# Epoch 61/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4620 - val_loss: 0.6805
# Epoch 62/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4613 - val_loss: 0.6819
# Epoch 63/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4610 - val_loss: 0.6794
# Epoch 64/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4605 - val_loss: 0.6756
# Epoch 65/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4597 - val_loss: 0.6736
# Epoch 66/200
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4591 - val_loss: 0.6755
# Epoch 67/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4585 - val_loss: 0.6780
# Epoch 68/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4582 - val_loss: 0.6766
# Epoch 69/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4575 - val_loss: 0.6812
# Epoch 70/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4568 - val_loss: 0.6830
# Epoch 71/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4566 - val_loss: 0.6772
# Epoch 72/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4558 - val_loss: 0.6760
# Epoch 73/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4553 - val_loss: 0.6799
# Epoch 74/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4548 - val_loss: 0.6814
# Epoch 75/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4542 - val_loss: 0.6789
# Epoch 76/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4538 - val_loss: 0.6776
# Epoch 77/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4532 - val_loss: 0.6760
# Epoch 78/200
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4528 - val_loss: 0.6766
# Epoch 79/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4521 - val_loss: 0.6746
# Epoch 80/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4518 - val_loss: 0.6806
# Epoch 81/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4513 - val_loss: 0.6795
# Epoch 82/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4506 - val_loss: 0.6814
# Epoch 83/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4505 - val_loss: 0.6730
# Epoch 84/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4500 - val_loss: 0.6821
# Epoch 85/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4496 - val_loss: 0.6829
# Epoch 86/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4491 - val_loss: 0.6725
# Epoch 87/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4487 - val_loss: 0.6764
# Epoch 88/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4485 - val_loss: 0.6874
# Epoch 89/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4476 - val_loss: 0.6791
# Epoch 90/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4475 - val_loss: 0.6889
# Epoch 91/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4472 - val_loss: 0.6844
# Epoch 92/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4466 - val_loss: 0.6868
# Epoch 93/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4464 - val_loss: 0.6862
# Epoch 94/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4458 - val_loss: 0.6800
# Epoch 95/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4456 - val_loss: 0.6811
# Epoch 96/200
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4451 - val_loss: 0.6800
# Epoch 97/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4448 - val_loss: 0.6814
# Epoch 98/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4445 - val_loss: 0.6855
# Epoch 99/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4442 - val_loss: 0.6857
# Epoch 100/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4437 - val_loss: 0.6842
# Epoch 101/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4434 - val_loss: 0.6862
# Epoch 102/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4431 - val_loss: 0.6764
# Epoch 103/200
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4429 - val_loss: 0.6872
# Epoch 104/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4425 - val_loss: 0.6811
# Epoch 105/200
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4421 - val_loss: 0.6922
# Epoch 106/200
# 200/200 [==============================] - 24s 121ms/step - loss: 0.4417 - val_loss: 0.6872
# Epoch 107/200
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4415 - val_loss: 0.6861
# Epoch 108/200
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4410 - val_loss: 0.6785
# Epoch 109/200
# 200/200 [==============================] - 26s 132ms/step - loss: 0.4408 - val_loss: 0.6809
# Epoch 110/200
# 200/200 [==============================] - 21s 107ms/step - loss: 0.4405 - val_loss: 0.6853
# Epoch 111/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4403 - val_loss: 0.6789
# Epoch 112/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4398 - val_loss: 0.6825
# Epoch 113/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4395 - val_loss: 0.6783
# Epoch 114/200
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4393 - val_loss: 0.6847
# Epoch 115/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4390 - val_loss: 0.6900
# Epoch 116/200
# 200/200 [==============================] - 26s 130ms/step - loss: 0.4386 - val_loss: 0.6852
# Epoch 117/200
# 200/200 [==============================] - 24s 119ms/step - loss: 0.4382 - val_loss: 0.6892
# Epoch 118/200
# 200/200 [==============================] - 25s 126ms/step - loss: 0.4381 - val_loss: 0.6829
# Epoch 119/200
# 200/200 [==============================] - 25s 125ms/step - loss: 0.4376 - val_loss: 0.6801
# Epoch 120/200
# 200/200 [==============================] - 25s 126ms/step - loss: 0.4375 - val_loss: 0.6832
# Epoch 121/200
# 200/200 [==============================] - 25s 126ms/step - loss: 0.4370 - val_loss: 0.6820
# Epoch 122/200
# 200/200 [==============================] - 25s 123ms/step - loss: 0.4368 - val_loss: 0.6852
# Epoch 123/200
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4366 - val_loss: 0.6877
# Epoch 124/200
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4362 - val_loss: 0.6806
# Epoch 125/200
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4360 - val_loss: 0.6800
# Epoch 126/200
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4357 - val_loss: 0.6834
# Epoch 127/200
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4354 - val_loss: 0.6773
# Epoch 128/200
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4350 - val_loss: 0.6922
# Epoch 129/200
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4349 - val_loss: 0.6877
# Epoch 130/200
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4345 - val_loss: 0.6810
# Epoch 131/200
# 200/200 [==============================] - 22s 112ms/step - loss: 0.4343 - val_loss: 0.6907
# Epoch 132/200
# 200/200 [==============================] - 24s 119ms/step - loss: 0.4341 - val_loss: 0.6902
# Epoch 133/200
# 200/200 [==============================] - 24s 119ms/step - loss: 0.4339 - val_loss: 0.6905
# Epoch 134/200
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4335 - val_loss: 0.6883
# Epoch 135/200
# 200/200 [==============================] - 23s 117ms/step - loss: 0.4332 - val_loss: 0.6975
# Epoch 136/200
# 200/200 [==============================] - 24s 119ms/step - loss: 0.4330 - val_loss: 0.6905
# Epoch 137/200
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4325 - val_loss: 0.6830
# Epoch 138/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4325 - val_loss: 0.6950
# Epoch 139/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4321 - val_loss: 0.6889
# Epoch 140/200
# 200/200 [==============================] - 21s 107ms/step - loss: 0.4317 - val_loss: 0.6826
# Epoch 141/200
# 200/200 [==============================] - 24s 121ms/step - loss: 0.4317 - val_loss: 0.6847
# Epoch 142/200
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4311 - val_loss: 0.6878
# Epoch 143/200
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4313 - val_loss: 0.6950
# Epoch 144/200
# 200/200 [==============================] - 22s 112ms/step - loss: 0.4309 - val_loss: 0.6926
# Epoch 145/200
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4306 - val_loss: 0.6922
# Epoch 146/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4303 - val_loss: 0.6916
# Epoch 147/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4301 - val_loss: 0.6867
# Epoch 148/200
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4298 - val_loss: 0.6898
# Epoch 149/200
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4297 - val_loss: 0.6948
# Epoch 150/200
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4295 - val_loss: 0.6889
# Epoch 151/200
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4293 - val_loss: 0.6861
# Epoch 152/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4290 - val_loss: 0.6885
# Epoch 153/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4288 - val_loss: 0.6960
# Epoch 154/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4285 - val_loss: 0.6862
# Epoch 155/200
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4281 - val_loss: 0.6970
# Epoch 156/200
# 200/200 [==============================] - 22s 112ms/step - loss: 0.4282 - val_loss: 0.6982
# Epoch 157/200
# 200/200 [==============================] - 24s 120ms/step - loss: 0.4277 - val_loss: 0.6925
# Epoch 158/200
# 200/200 [==============================] - 26s 131ms/step - loss: 0.4277 - val_loss: 0.6913
# Epoch 159/200
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4272 - val_loss: 0.6957
# Epoch 160/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4272 - val_loss: 0.6914
# Epoch 161/200
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4270 - val_loss: 0.6986
# Epoch 162/200
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4266 - val_loss: 0.6889
# Epoch 163/200
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4265 - val_loss: 0.6975
# Epoch 164/200
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4264 - val_loss: 0.6983
# Epoch 165/200
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4261 - val_loss: 0.6950
# Epoch 166/200
# 200/200 [==============================] - 21s 107ms/step - loss: 0.4259 - val_loss: 0.6906
# Epoch 167/200
# 200/200 [==============================] - 23s 117ms/step - loss: 0.4258 - val_loss: 0.6879
# Epoch 168/200
# 200/200 [==============================] - 25s 127ms/step - loss: 0.4256 - val_loss: 0.6887
# Epoch 169/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4255 - val_loss: 0.6886
# Epoch 170/200
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4251 - val_loss: 0.6998
# Epoch 171/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4249 - val_loss: 0.6982
# Epoch 172/200
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4246 - val_loss: 0.6967
# Epoch 173/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4246 - val_loss: 0.6968
# Epoch 174/200
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4241 - val_loss: 0.6924
# Epoch 175/200
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4242 - val_loss: 0.6981
# Epoch 176/200
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4237 - val_loss: 0.6973
# Epoch 177/200
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4237 - val_loss: 0.6965
# Epoch 178/200
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4234 - val_loss: 0.6955
# Epoch 179/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4233 - val_loss: 0.7015
# Epoch 180/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4230 - val_loss: 0.6956
# Epoch 181/200
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4228 - val_loss: 0.7022
# Epoch 182/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4228 - val_loss: 0.6978
# Epoch 183/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4224 - val_loss: 0.6928
# Epoch 184/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4221 - val_loss: 0.7008
# Epoch 185/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4220 - val_loss: 0.7030
# Epoch 186/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4218 - val_loss: 0.6974
# Epoch 187/200
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4215 - val_loss: 0.6945
# Epoch 188/200
# 200/200 [==============================] - 22s 112ms/step - loss: 0.4214 - val_loss: 0.6978
# Epoch 189/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4211 - val_loss: 0.7017
# Epoch 190/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4208 - val_loss: 0.6995
# Epoch 191/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4207 - val_loss: 0.7058
# Epoch 192/200
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4204 - val_loss: 0.7013
# Epoch 193/200
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4201 - val_loss: 0.7052
# Epoch 194/200
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4199 - val_loss: 0.6948
# Epoch 195/200
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4196 - val_loss: 0.7039
# Epoch 196/200
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4196 - val_loss: 0.6996
# Epoch 197/200
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4192 - val_loss: 0.7012
# Epoch 198/200
# 200/200 [==============================] - 21s 107ms/step - loss: 0.4190 - val_loss: 0.6917
# Epoch 199/200
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4186 - val_loss: 0.6959
# Epoch 200/200
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4185 - val_loss: 0.7033

# %%
for x, y in val_data_multi.take(3):
    multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])
