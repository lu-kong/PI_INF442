# %%
from util import *
import numpy as np
from matplotlib import pyplot as plt

# %%
df = load_data('p',2007)

# %%
df_w = load_data()
df_w.head(10)
# Out:
#    numer_sta            date    pmer tend cod_tend   dd         ff  \
# 0       7005  20070101000000  101560   70        3  260   9.800000
# 1       7015  20070101000000  101300  -90        5  270   9.800000
# 2       7020  20070101000000  101600   50        0  250  14.900000
# 3       7027  20070101000000  101800  170        1  240  11.800000
# 4       7037  20070101000000  101760   30        3  270   8.700000
# 5       7110  20070101000000  102130  120        1  260   7.200000
# 6       7117  20070101000000  101940   80        1  260  10.800000
# 7       7130  20070101000000  102230  130        3  240   6.200000
# 8       7139  20070101000000  102050   60        1  250   8.700000
# 9       7149  20070101000000  101960  -70        6  220   9.800000
#
#             t          td   u  ... nnuage2 ctype2 hnuage2 nnuage3 ctype3  \
# 0  283.650000  280.750000  82  ...      mq     mq      mq      mq     mq
# 1  285.250000  281.950000  80  ...      mq     mq      mq      mq     mq
# 2  285.550000  282.150000  80  ...      mq     mq      mq      mq     mq
# 3  285.050000  281.550000  79  ...      mq     mq      mq      mq     mq
# 4  284.450000  280.750000  78  ...      mq     mq      mq      mq     mq
# 5  283.950000  279.350000  73  ...      mq     mq      mq      mq     mq
# 6  284.750000  281.250000  79  ...      mq     mq      mq      mq     mq
# 7  285.650000  282.450000  81  ...      mq     mq      mq      mq     mq
# 8  286.350000  282.450000  77  ...      mq     mq      mq      mq     mq
# 9  286.650000  284.850000  89  ...      mq     mq      mq      mq     mq
#
#   hnuage3 nnuage4 ctype4 hnuage4 Unnamed: 59
# 0      mq      mq     mq      mq         NaN
# 1      mq      mq     mq      mq         NaN
# 2      mq      mq     mq      mq         NaN
# 3      mq      mq     mq      mq         NaN
# 4      mq      mq     mq      mq         NaN
# 5      mq      mq     mq      mq         NaN
# 6      mq      mq     mq      mq         NaN
# 7      mq      mq     mq      mq         NaN
# 8      mq      mq     mq      mq         NaN
# 9      mq      mq     mq      mq         NaN
#
# [10 rows x 60 columns]

# %%
orly = df_w[df_w['numer_sta']==7149] # for filtering the data of 7149 station

# %%
orly.head(10)
# Out:
#      numer_sta            date    pmer  tend cod_tend   dd        ff  \
# 9         7149  20070101000000  101960   -70        6  220  9.800000
# 68        7149  20070101030000  102010    40        3  240  7.200000
# 127       7149  20070101060000  102040    30        3  230  8.700000
# 186       7149  20070101090000  102240   190        3  250  9.800000
# 245       7149  20070101120000  102450   210        0  270  8.700000
# 304       7149  20070101150000  102320  -130        6  210  5.100000
# 363       7149  20070101180000  101920  -400        8  170  3.100000
# 421       7149  20070101210000  101660  -270        8  220  7.200000
# 479       7149  20070102000000  102090   430        3  280  9.800000
# 536       7149  20070102030000  102540   440        1  270  6.200000
#
#               t          td   u  ... nnuage2 ctype2 hnuage2 nnuage3 ctype3  \
# 9    286.650000  284.850000  89  ...      mq     mq      mq      mq     mq
# 68   285.650000  282.250000  80  ...      mq     mq      mq      mq     mq
# 127  283.650000  279.750000  77  ...      mq     mq      mq      mq     mq
# 186  282.050000  278.050000  76  ...       4      6     780      mq     mq
# 245  283.650000  276.650000  62  ...       4      0    6900      mq     mq
# 304  282.550000  276.950000  68  ...       8      4    3900      mq     mq
# 363  281.150000  277.950000  80  ...       3      6    1200       8      3
# 421  279.150000  277.750000  91  ...       7      6     330      mq     mq
# 479  280.050000  276.350000  77  ...      mq     mq      mq      mq     mq
# 536  278.650000  275.850000  82  ...       3      6     900      mq     mq
#
#     hnuage3 nnuage4 ctype4 hnuage4 Unnamed: 59
# 9        mq      mq     mq      mq         NaN
# 68       mq      mq     mq      mq         NaN
# 127      mq      mq     mq      mq         NaN
# 186      mq      mq     mq      mq         NaN
# 245      mq      mq     mq      mq         NaN
# 304      mq      mq     mq      mq         NaN
# 363    3000      mq     mq      mq         NaN
# 421      mq      mq     mq      mq         NaN
# 479      mq      mq     mq      mq         NaN
# 536      mq      mq     mq      mq         NaN
#
# [10 rows x 60 columns]

# %% [markdown]
# # power

# %% [markdown]
# ## 1. presentations of data

# %% [markdown]
# ### one day

# %%
test = df[df['date']=='1/1/2007']
gap = test['sub_1_kitchen']
plt.plot(np.linspace(0.0,24.0,num = 1440),gap.values.astype('float'))
plt.show()

# %% [markdown]
# ### combine some days

# %%
test = time_rescale(df)
test
# Out:
# Processe begin...
#
# Begin configuring datetime line ...done
# Begin dropping bug data ... done
# C:\Users\lu\Anaconda3\envs\tf2\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# done
#                      g_active_power  g_reactive_power     voltage  \
# full_time
# 2007-01-01 00:00:00        2.552122          0.097033  241.886000
# 2007-01-01 03:00:00        2.497878          0.093311  242.690167
# 2007-01-01 06:00:00        2.448244          0.090367  240.893056
# 2007-01-01 09:00:00        2.794622          0.083011  238.509500
# 2007-01-01 12:00:00        2.024222          0.143100  239.028056
# ...                             ...               ...         ...
# 2007-12-31 09:00:00        2.072356          0.113089  239.232444
# 2007-12-31 12:00:00        2.294333          0.216144  240.895111
# 2007-12-31 15:00:00        2.267200          0.094244  241.277222
# 2007-12-31 18:00:00        2.800967          0.074589  236.184778
# 2007-12-31 21:00:00        1.599567          0.064433  239.880944
#
#                      global_intensity  sub_1_kitchen  sub_2_laundry  \
# full_time
# 2007-01-01 00:00:00         10.504444            0.0       0.305556
# 2007-01-01 03:00:00         10.220000            0.0       0.283333
# 2007-01-01 06:00:00         10.090000            0.0       0.200000
# 2007-01-01 09:00:00         11.650000            0.0       0.194444
# 2007-01-01 12:00:00          8.527778            0.0       0.266667
# ...                               ...            ...            ...
# 2007-12-31 09:00:00          8.706667            0.0       9.138889
# 2007-12-31 12:00:00          9.638889            0.0       8.838889
# 2007-12-31 15:00:00          9.406667            0.0       0.161111
# 2007-12-31 18:00:00         11.831111            0.0       0.316667
# 2007-12-31 21:00:00          6.602222            0.0       0.155556
#
#                      sub_3_wh_ac
# full_time
# 2007-01-01 00:00:00     0.000000
# 2007-01-01 03:00:00     0.000000
# 2007-01-01 06:00:00     0.000000
# 2007-01-01 09:00:00     4.838889
# 2007-01-01 12:00:00     3.016667
# ...                          ...
# 2007-12-31 09:00:00     3.738889
# 2007-12-31 12:00:00    17.800000
# 2007-12-31 15:00:00    17.855556
# 2007-12-31 18:00:00    17.127778
# 2007-12-31 21:00:00    17.655556
#
# [2920 rows x 7 columns]

# %%
df_comb = df.copy()

# %%
df_comb
# Out:
#               date      time g_active_power g_reactive_power  voltage  \
# 0         1/1/2007  00:00:00          2.580            0.136  241.970
# 1         1/1/2007  00:01:00          2.552            0.100  241.750
# 2         1/1/2007  00:02:00          2.550            0.100  241.640
# 3         1/1/2007  00:03:00          2.550            0.100  241.710
# 4         1/1/2007  00:04:00          2.554            0.100  241.980
# ...            ...       ...            ...              ...      ...
# 525595  31/12/2007  23:55:00          1.746            0.204   242.41
# 525596  31/12/2007  23:56:00          1.732             0.21   242.42
# 525597  31/12/2007  23:57:00          1.732             0.21    242.5
# 525598  31/12/2007  23:58:00          1.684            0.144   242.18
# 525599  31/12/2007  23:59:00          1.628            0.072   241.79
#
#        global_intensity sub_1_kitchen sub_2_laundry  sub_3_wh_ac
# 0                10.600         0.000         0.000          0.0
# 1                10.400         0.000         0.000          0.0
# 2                10.400         0.000         0.000          0.0
# 3                10.400         0.000         0.000          0.0
# 4                10.400         0.000         0.000          0.0
# ...                 ...           ...           ...          ...
# 525595              7.2             0             0         18.0
# 525596              7.2             0             0         18.0
# 525597              7.2             0             0         18.0
# 525598                7             0             0         18.0
# 525599              6.6             0             0         18.0
#
# [525600 rows x 9 columns]

# %%
df_comb['full_time'] = df_comb['date']+' '+ df_comb['time']
df_comb['full_time'] = pd.to_datetime(df_comb['full_time'])

# %%
df_comb
# Out:
#               date      time g_active_power g_reactive_power  voltage  \
# 0         1/1/2007  00:00:00          2.580            0.136  241.970
# 1         1/1/2007  00:01:00          2.552            0.100  241.750
# 2         1/1/2007  00:02:00          2.550            0.100  241.640
# 3         1/1/2007  00:03:00          2.550            0.100  241.710
# 4         1/1/2007  00:04:00          2.554            0.100  241.980
# ...            ...       ...            ...              ...      ...
# 525595  31/12/2007  23:55:00          1.746            0.204   242.41
# 525596  31/12/2007  23:56:00          1.732             0.21   242.42
# 525597  31/12/2007  23:57:00          1.732             0.21    242.5
# 525598  31/12/2007  23:58:00          1.684            0.144   242.18
# 525599  31/12/2007  23:59:00          1.628            0.072   241.79
#
#        global_intensity sub_1_kitchen sub_2_laundry  sub_3_wh_ac  \
# 0                10.600         0.000         0.000          0.0
# 1                10.400         0.000         0.000          0.0
# 2                10.400         0.000         0.000          0.0
# 3                10.400         0.000         0.000          0.0
# 4                10.400         0.000         0.000          0.0
# ...                 ...           ...           ...          ...
# 525595              7.2             0             0         18.0
# 525596              7.2             0             0         18.0
# 525597              7.2             0             0         18.0
# 525598                7             0             0         18.0
# 525599              6.6             0             0         18.0
#
#                  full_time
# 0      2007-01-01 00:00:00
# 1      2007-01-01 00:01:00
# 2      2007-01-01 00:02:00
# 3      2007-01-01 00:03:00
# 4      2007-01-01 00:04:00
# ...                    ...
# 525595 2007-12-31 23:55:00
# 525596 2007-12-31 23:56:00
# 525597 2007-12-31 23:57:00
# 525598 2007-12-31 23:58:00
# 525599 2007-12-31 23:59:00
#
# [525600 rows x 10 columns]

# %%
df_dropped = df_comb.dropna(how = 'any')

# %%
df_dropped.iloc[:,2:-1] = df_dropped.iloc[:,2:-1].apply(pd.to_numeric)
df_dropped
# Out:
# C:\Users\lu\Anaconda3\envs\tf2\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#               date      time  g_active_power  g_reactive_power  voltage  \
# 0         1/1/2007  00:00:00           2.580             0.136   241.97
# 1         1/1/2007  00:01:00           2.552             0.100   241.75
# 2         1/1/2007  00:02:00           2.550             0.100   241.64
# 3         1/1/2007  00:03:00           2.550             0.100   241.71
# 4         1/1/2007  00:04:00           2.554             0.100   241.98
# ...            ...       ...             ...               ...      ...
# 525595  31/12/2007  23:55:00           1.746             0.204   242.41
# 525596  31/12/2007  23:56:00           1.732             0.210   242.42
# 525597  31/12/2007  23:57:00           1.732             0.210   242.50
# 525598  31/12/2007  23:58:00           1.684             0.144   242.18
# 525599  31/12/2007  23:59:00           1.628             0.072   241.79
#
#         global_intensity  sub_1_kitchen  sub_2_laundry  sub_3_wh_ac  \
# 0                   10.6            0.0            0.0          0.0
# 1                   10.4            0.0            0.0          0.0
# 2                   10.4            0.0            0.0          0.0
# 3                   10.4            0.0            0.0          0.0
# 4                   10.4            0.0            0.0          0.0
# ...                  ...            ...            ...          ...
# 525595               7.2            0.0            0.0         18.0
# 525596               7.2            0.0            0.0         18.0
# 525597               7.2            0.0            0.0         18.0
# 525598               7.0            0.0            0.0         18.0
# 525599               6.6            0.0            0.0         18.0
#
#                  full_time
# 0      2007-01-01 00:00:00
# 1      2007-01-01 00:01:00
# 2      2007-01-01 00:02:00
# 3      2007-01-01 00:03:00
# 4      2007-01-01 00:04:00
# ...                    ...
# 525595 2007-12-31 23:55:00
# 525596 2007-12-31 23:56:00
# 525597 2007-12-31 23:57:00
# 525598 2007-12-31 23:58:00
# 525599 2007-12-31 23:59:00
#
# [521669 rows x 10 columns]

# %%
df_dropped.iloc[:,2:].resample('B',on = 'full_time').max()
# Out:
#             g_active_power  g_reactive_power  voltage  global_intensity  \
# full_time
# 2007-01-01           3.558             0.454   246.30              14.6
# 2007-01-02           7.482             0.500   245.73              32.0
# 2007-01-03           1.472             0.378   246.98               6.2
# 2007-01-04           8.160             0.838   246.56              35.0
# 2007-01-05           6.096             0.764   244.04              27.0
# ...                    ...               ...      ...               ...
# 2007-12-25           6.756             0.568   249.30              28.4
# 2007-12-26           6.394             0.574   250.78              26.4
# 2007-12-27           7.924             0.738   249.34              34.4
# 2007-12-28           9.590             0.660   251.21              41.2
# 2007-12-31           6.158             0.854   248.41              26.8
#
#             sub_1_kitchen  sub_2_laundry  sub_3_wh_ac           full_time
# full_time
# 2007-01-01            0.0            2.0         19.0 2007-01-01 23:59:00
# 2007-01-02           38.0            2.0         19.0 2007-01-02 23:59:00
# 2007-01-03            0.0            2.0         19.0 2007-01-03 23:59:00
# 2007-01-04           73.0           73.0         19.0 2007-01-04 23:59:00
# 2007-01-05           38.0           37.0         19.0 2007-01-07 23:59:00
# ...                   ...            ...          ...                 ...
# 2007-12-25           53.0           39.0         20.0 2007-12-25 23:59:00
# 2007-12-26           40.0           39.0         19.0 2007-12-26 23:59:00
# 2007-12-27           39.0           36.0         19.0 2007-12-27 23:59:00
# 2007-12-28           41.0           77.0         20.0 2007-12-30 23:59:00
# 2007-12-31            0.0           39.0         19.0 2007-12-31 23:59:00
#
# [261 rows x 8 columns]

# %%
mode = 'm'
assert mode in ('mean','sum','max') ,"mode is to be choosen from ('mean','max','sum')"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-85-2f1fa550b3ed> in <module>
#       1 mode = 'm'
# ----> 2 assert mode in ('mean','sum','max') ,"mode to rescale, choosen from ('mean','max','sum')"
#
# AssertionError: mode to rescale, choosen from ('mean','max','sum')

# %%
rs = df_comb.iloc[:,2:]

# %% [markdown]
# #### test for module

# %%
def time_rescale(df,timescale = '3H',how='any',mode = 'mean'):
    """
    parameters:
    -----------------------------------------
    df       : Dataframe (support only data of power_consumption for instance)
    timescae : Time scale to change to, chosen generally from 'XT','XH','XD'...X is a number to be chosen
    how      : usuel for dropping unfilled rows  how = 'any' by default
    mode     : mode to rescale, choosen from ('mean','max','sum')
    return:
    -----------------------------------------
    df cleaned and rescaled indexed by 'full_time'
    """
    assert mode in ('mean','sum','max') ,"mode is to be choosen from ('mean','max','sum')"
    
    print('Processe begin...\n')
    df_comb = df.copy()
    print('Begin configuring datetime line ...',end='')
    df_comb['full_time'] = df_comb['date']+' '+ df_comb['time']
    df_comb['full_time'] = pd.to_datetime(df_comb['full_time'])
    print('done')
    print('Begin dropping bug data ...',end='')
    df_dropped = df_comb.dropna(how = how)
    print(' done')
    df_dropped.iloc[:,2:-1] = df_dropped.iloc[:,2:-1].apply(pd.to_numeric)
    if(mode == 'sum'):
        res = df_dropped.iloc[:,2:].resample(timescale,on = 'full_time').sum()
    if(mode == 'mean'):
        res = df_dropped.iloc[:,2:].resample(timescale,on = 'full_time').mean()
    if(mode == 'max'):
        res = df_dropped.iloc[:,2:].resample(timescale,on = 'full_time').max()
    print('done\n')
    return res

# %%
test = time_rescale(df,'7D')
test
# Out:
# Processe begin...
#
# Begin configuring datetime line ...done
# Begin dropping bug data ... done
# C:\Users\lu\Anaconda3\envs\tf2\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# done
#             g_active_power  g_reactive_power     voltage  global_intensity  \
# full_time
# 2007-01-01        1.152170          0.109718  238.848376          4.885524
# 2007-01-08        1.422602          0.146245  238.996149          6.068642
# 2007-01-15        1.639451          0.136597  240.440150          6.968413
# 2007-01-22        1.517470          0.106522  241.991723          6.397440
# 2007-01-29        1.137664          0.113477  240.860212          4.792143
# 2007-02-05        0.970162          0.112586  237.638231          4.189187
# 2007-02-12        1.632337          0.146270  240.321322          6.901766
# 2007-02-19        1.320603          0.106851  240.138894          5.560488
# 2007-02-26        0.904076          0.107258  241.519683          3.827044
# 2007-03-05        0.806891          0.106489  237.663104          3.494782
# 2007-03-12        1.272973          0.106568  240.262135          5.386905
# 2007-03-19        1.532828          0.110405  240.778019          6.445798
# 2007-03-26        1.450084          0.131234  240.424341          6.134782
# 2007-04-02        1.170303          0.131447  238.052862          5.022560
# 2007-04-09        0.842081          0.107211  240.172366          3.588710
# 2007-04-16        0.886208          0.133414  240.054920          3.833373
# 2007-04-23        0.795370          0.105807  235.500612          3.503975
# 2007-04-30        1.335267          0.138063  238.466545          5.708485
# 2007-05-07        0.968601          0.121814  238.590098          4.167282
# 2007-05-14        1.024428          0.119391  235.531253          4.462540
# 2007-05-21        1.007194          0.110750  234.993796          4.361548
# 2007-05-28        0.920197          0.105346  237.493447          3.965853
# 2007-06-04        1.013378          0.127851  237.605824          4.387360
# 2007-06-11        1.161818          0.158884  239.834672          4.985595
# 2007-06-18        0.512064          0.138882  240.580545          2.285354
# 2007-06-25        0.980306          0.143343  240.113600          4.234666
# 2007-07-02        1.163452          0.116480  237.904521          4.959345
# 2007-07-09        1.010649          0.138131  240.113365          4.343377
# 2007-07-16        0.650334          0.141988  234.626702          2.919476
# 2007-07-23        0.630839          0.089054  235.317376          2.791845
# 2007-07-30        1.021048          0.111770  238.248591          4.358730
# 2007-08-06        1.055761          0.113394  238.598326          4.526310
# 2007-08-13        0.696895          0.095327  239.107339          3.001607
# 2007-08-20        0.835948          0.144861  240.520540          3.618573
# 2007-08-27        0.885740          0.138814  240.429327          3.801151
# 2007-09-03        0.889307          0.117560  238.674101          3.839454
# 2007-09-10        1.107446          0.119036  239.383404          4.743532
# 2007-09-17        0.894429          0.120376  239.408657          3.865476
# 2007-09-24        1.173551          0.120606  239.194121          4.997043
# 2007-10-01        1.111431          0.138645  239.757773          4.764206
# 2007-10-08        1.157807          0.105737  238.882760          4.949008
# 2007-10-15        1.191872          0.096979  240.016497          5.033631
# 2007-10-22        1.097689          0.082758  240.686503          4.651935
# 2007-10-29        1.273233          0.107559  240.568880          5.370516
# 2007-11-05        0.812594          0.107821  238.696162          3.504623
# 2007-11-12        1.504285          0.099512  240.908805          6.309623
# 2007-11-19        1.321658          0.091641  241.764778          5.544022
# 2007-11-26        1.330046          0.096668  241.883901          5.588848
# 2007-12-03        0.838091          0.120684  238.886729          3.625992
# 2007-12-10        1.486147          0.096026  241.223161          6.239960
# 2007-12-17        1.544693          0.089493  242.717135          6.432880
# 2007-12-24        1.888514          0.120793  242.152803          7.888413
# 2007-12-31        1.539265          0.101067  241.094792          6.455000
#
#             sub_1_kitchen  sub_2_laundry  sub_3_wh_ac
# full_time
# 2007-01-01       1.068856       0.860105     6.093263
# 2007-01-08       2.438457       1.494035     6.925731
# 2007-01-15       2.324901       1.991567     8.086508
# 2007-01-22       1.138506       1.482588     7.149717
# 2007-01-29       0.396925       0.960516     7.437004
# 2007-02-05       1.085813       1.961806     5.512599
# 2007-02-12       1.429067       2.677282     7.090675
# 2007-02-19       0.856122       1.562512     6.212046
# 2007-02-26       0.830952       0.723313     4.123016
# 2007-03-05       0.983730       2.012798     4.062996
# 2007-03-12       1.572817       2.007242     5.842758
# 2007-03-19       1.694116       2.040480     8.163409
# 2007-03-26       0.807242       2.789881     7.361111
# 2007-04-02       1.490675       1.757738     6.026687
# 2007-04-09       0.628968       1.619246     4.171528
# 2007-04-16       1.657143       0.671032     4.539980
# 2007-04-23       0.778701       0.679961     4.627614
# 2007-04-30       1.931749       2.533529     5.955078
# 2007-05-07       1.129960       0.830456     5.278770
# 2007-05-14       1.961905       1.669643     4.994841
# 2007-05-21       1.750099       2.104762     5.111111
# 2007-05-28       1.017857       1.126190     3.985020
# 2007-06-04       1.518603       1.492410     5.560175
# 2007-06-11       1.965972       2.220635     5.878671
# 2007-06-18       0.363763       0.851359     2.654098
# 2007-06-25       1.484076       2.521083     5.441115
# 2007-07-02       0.879663       2.205754     6.550893
# 2007-07-09       1.634975       1.613065     5.379598
# 2007-07-16       1.318087       0.776764     3.309158
# 2007-07-23       0.542262       1.685813     3.088194
# 2007-07-30       1.216667       0.666071     5.236508
# 2007-08-06       1.177183       2.011012     5.887500
# 2007-08-13       0.358433       1.049702     4.980952
# 2007-08-20       1.405199       1.856930     4.419288
# 2007-08-27       1.092262       1.469940     4.888690
# 2007-09-03       1.087333       1.656343     5.353615
# 2007-09-10       1.131349       1.672619     5.835714
# 2007-09-17       1.636905       1.207540     5.061806
# 2007-09-24       1.037408       2.779024     5.866938
# 2007-10-01       1.527381       1.799206     5.242361
# 2007-10-08       1.173810       1.710119     5.444643
# 2007-10-15       1.057738       1.662401     6.800397
# 2007-10-22       0.831316       1.366243     5.624826
# 2007-10-29       0.854960       1.822520     5.691468
# 2007-11-05       1.005853       0.378869     4.667063
# 2007-11-12       1.435417       1.842460     8.262302
# 2007-11-19       1.330191       1.552138     7.247346
# 2007-11-26       0.753150       2.097331     7.347852
# 2007-12-03       0.762302       1.176091     5.082639
# 2007-12-10       1.030655       2.054762     8.114385
# 2007-12-17       1.273142       1.669610     8.316004
# 2007-12-24       2.303075       2.433730     8.441270
# 2007-12-31       0.000000       2.400694     9.771528

# %%
rss = rs.iloc[:19000,:-1].apply(pd.to_numeric)
rss['full_time'] = df_comb['full_time']
rss
# Out:
#        g_active_power  g_reactive_power  voltage  global_intensity  \
# 0               2.580             0.136   241.97              10.6
# 1               2.552             0.100   241.75              10.4
# 2               2.550             0.100   241.64              10.4
# 3               2.550             0.100   241.71              10.4
# 4               2.554             0.100   241.98              10.4
# ...               ...               ...      ...               ...
# 18995           0.214             0.000   242.30               0.8
# 18996           0.496             0.000   241.38               3.8
# 18997           2.382             0.108   239.62               9.8
# 18998           2.382             0.112   240.13               9.8
# 18999           0.702             0.140   242.63               4.4
#
#        sub_1_kitchen  sub_2_laundry  sub_3_wh_ac           full_time
# 0                0.0            0.0          0.0 2007-01-01 00:00:00
# 1                0.0            0.0          0.0 2007-01-01 00:01:00
# 2                0.0            0.0          0.0 2007-01-01 00:02:00
# 3                0.0            0.0          0.0 2007-01-01 00:03:00
# 4                0.0            0.0          0.0 2007-01-01 00:04:00
# ...              ...            ...          ...                 ...
# 18995            0.0            0.0          0.0 2007-01-14 04:35:00
# 18996            0.0            0.0          0.0 2007-01-14 04:36:00
# 18997            0.0            0.0          0.0 2007-01-14 04:37:00
# 18998            0.0            0.0          0.0 2007-01-14 04:38:00
# 18999            0.0            0.0          0.0 2007-01-14 04:39:00
#
# [19000 rows x 8 columns]

# %%
rsed = rss.resample('2H',on='full_time').mean()
rsed.head(10)
# Out:
#                      g_active_power  g_reactive_power     voltage  \
# full_time
# 2007-01-01 00:00:00        2.537017          0.092217  241.228917
# 2007-01-01 02:00:00        2.562000          0.098383  243.232917
# 2007-01-01 04:00:00        2.475983          0.094917  242.402417
# 2007-01-01 06:00:00        2.451500          0.096500  240.768000
# 2007-01-01 08:00:00        2.793933          0.072850  240.461000
# 2007-01-01 10:00:00        2.618867          0.090717  237.874833
# 2007-01-01 12:00:00        2.389133          0.094033  238.213750
# 2007-01-01 14:00:00        1.601783          0.176050  239.785917
# 2007-01-01 16:00:00        1.511083          0.120067  238.431917
# 2007-01-01 18:00:00        1.097100          0.098183  238.047167
#
#                      global_intensity  sub_1_kitchen  sub_2_laundry  \
# full_time
# 2007-01-01 00:00:00         10.486667            0.0       0.291667
# 2007-01-01 02:00:00         10.470000            0.0       0.300000
# 2007-01-01 04:00:00         10.130000            0.0       0.291667
# 2007-01-01 06:00:00         10.111667            0.0       0.275000
# 2007-01-01 08:00:00         11.550000            0.0       0.025000
# 2007-01-01 10:00:00         10.948333            0.0       0.291667
# 2007-01-01 12:00:00          9.986667            0.0       0.283333
# 2007-01-01 14:00:00          6.770000            0.0       0.291667
# 2007-01-01 16:00:00          6.290000            0.0       0.291667
# 2007-01-01 18:00:00          4.563333            0.0       0.233333
#
#                      sub_3_wh_ac
# full_time
# 2007-01-01 00:00:00     0.000000
# 2007-01-01 02:00:00     0.000000
# 2007-01-01 04:00:00     0.000000
# 2007-01-01 06:00:00     0.000000
# 2007-01-01 08:00:00     6.016667
# 2007-01-01 10:00:00     1.241667
# 2007-01-01 12:00:00     0.000000
# 2007-01-01 14:00:00    13.266667
# 2007-01-01 16:00:00    17.416667
# 2007-01-01 18:00:00    11.058333

# %%
rss =  rs.iloc[:19000,:-1].apply(pd.to_numeric)

# %%
ts = pd.Series(rs.all,index = df_comb['full_time'])

# %%
rss['full_time'] = df_comb.iloc[:19000,-1]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-7687882abd59> in <module>
# ----> 1 x = pd.DataFrame.mean()
#
# TypeError: stat_func() missing 1 required positional argument: 'self'

# %%
x = 
df_dropped.resample('3H',on='full_time').x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-828ea6bb6fd1> in <module>
# ----> 1 df_comb.resample('D').mean()
#
# ~\Anaconda3\envs\tf2\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8113             base=base,
#    8114             key=on,
# -> 8115             level=level,
#    8116         )
#    8117
#
# ~\Anaconda3\envs\tf2\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# ~\Anaconda3\envs\tf2\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1402
#    1403         raise TypeError(
# -> 1404             "Only valid with DatetimeIndex, "
#    1405             "TimedeltaIndex or PeriodIndex, "
#    1406             f"but got an instance of '{type(ax).__name__}'"
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %%
df_comb['g_active_power'].resample('D')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-20aac9028cdf> in <module>
# ----> 1 df_comb['g_active_power'].resample('D')
#
# ~\Anaconda3\envs\tf2\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8113             base=base,
#    8114             key=on,
# -> 8115             level=level,
#    8116         )
#    8117
#
# ~\Anaconda3\envs\tf2\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# ~\Anaconda3\envs\tf2\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1402
#    1403         raise TypeError(
# -> 1404             "Only valid with DatetimeIndex, "
#    1405             "TimedeltaIndex or PeriodIndex, "
#    1406             f"but got an instance of '{type(ax).__name__}'"
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %%
rng = pd.date_range('1/1/2000',periods=100,freq='D')

# %%
pd.to_datetime(( df['date'], df['time']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-a947657920ce> in <module>
# ----> 1 pd.to_datetime(( df['date'], df['time']))
#
# ~\Anaconda3\envs\tf2\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     752             result = _convert_and_box_cache(arg, cache_array)
#     753         else:
# --> 754             result = convert_listlike(arg, format)
#     755     else:
#     756         result = convert_listlike(np.array([arg]), format)[0]
#
# ~\Anaconda3\envs\tf2\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     355     elif getattr(arg, "ndim", 1) > 1:
#     356         raise TypeError(
# --> 357             "arg must be a string, datetime, list, tuple, 1-d array, or Series"
#     358         )
#     359
#
# TypeError: arg must be a string, datetime, list, tuple, 1-d array, or Series

# %%
uni = np.unique(df['date'].values)

# %%
uni
# Out:
# array(['1/1/2007', '1/10/2007', '1/11/2007', '1/12/2007', '1/2/2007',
#        '1/3/2007', '1/4/2007', '1/5/2007', '1/6/2007', '1/7/2007',
#        '1/8/2007', '1/9/2007', '10/1/2007', '10/10/2007', '10/11/2007',
#        '10/12/2007', '10/2/2007', '10/3/2007', '10/4/2007', '10/5/2007',
#        '10/6/2007', '10/7/2007', '10/8/2007', '10/9/2007', '11/1/2007',
#        '11/10/2007', '11/11/2007', '11/12/2007', '11/2/2007', '11/3/2007',
#        '11/4/2007', '11/5/2007', '11/6/2007', '11/7/2007', '11/8/2007',
#        '11/9/2007', '12/1/2007', '12/10/2007', '12/11/2007', '12/12/2007',
#        '12/2/2007', '12/3/2007', '12/4/2007', '12/5/2007', '12/6/2007',
#        '12/7/2007', '12/8/2007', '12/9/2007', '13/1/2007', '13/10/2007',
#        '13/11/2007', '13/12/2007', '13/2/2007', '13/3/2007', '13/4/2007',
#        '13/5/2007', '13/6/2007', '13/7/2007', '13/8/2007', '13/9/2007',
#        '14/1/2007', '14/10/2007', '14/11/2007', '14/12/2007', '14/2/2007',
#        '14/3/2007', '14/4/2007', '14/5/2007', '14/6/2007', '14/7/2007',
#        '14/8/2007', '14/9/2007', '15/1/2007', '15/10/2007', '15/11/2007',
#        '15/12/2007', '15/2/2007', '15/3/2007', '15/4/2007', '15/5/2007',
#        '15/6/2007', '15/7/2007', '15/8/2007', '15/9/2007', '16/1/2007',
#        '16/10/2007', '16/11/2007', '16/12/2007', '16/2/2007', '16/3/2007',
#        '16/4/2007', '16/5/2007', '16/6/2007', '16/7/2007', '16/8/2007',
#        '16/9/2007', '17/1/2007', '17/10/2007', '17/11/2007', '17/12/2007',
#        '17/2/2007', '17/3/2007', '17/4/2007', '17/5/2007', '17/6/2007',
#        '17/7/2007', '17/8/2007', '17/9/2007', '18/1/2007', '18/10/2007',
#        '18/11/2007', '18/12/2007', '18/2/2007', '18/3/2007', '18/4/2007',
#        '18/5/2007', '18/6/2007', '18/7/2007', '18/8/2007', '18/9/2007',
#        '19/1/2007', '19/10/2007', '19/11/2007', '19/12/2007', '19/2/2007',
#        '19/3/2007', '19/4/2007', '19/5/2007', '19/6/2007', '19/7/2007',
#        '19/8/2007', '19/9/2007', '2/1/2007', '2/10/2007', '2/11/2007',
#        '2/12/2007', '2/2/2007', '2/3/2007', '2/4/2007', '2/5/2007',
#        '2/6/2007', '2/7/2007', '2/8/2007', '2/9/2007', '20/1/2007',
#        '20/10/2007', '20/11/2007', '20/12/2007', '20/2/2007', '20/3/2007',
#        '20/4/2007', '20/5/2007', '20/6/2007', '20/7/2007', '20/8/2007',
#        '20/9/2007', '21/1/2007', '21/10/2007', '21/11/2007', '21/12/2007',
#        '21/2/2007', '21/3/2007', '21/4/2007', '21/5/2007', '21/6/2007',
#        '21/7/2007', '21/8/2007', '21/9/2007', '22/1/2007', '22/10/2007',
#        '22/11/2007', '22/12/2007', '22/2/2007', '22/3/2007', '22/4/2007',
#        '22/5/2007', '22/6/2007', '22/7/2007', '22/8/2007', '22/9/2007',
#        '23/1/2007', '23/10/2007', '23/11/2007', '23/12/2007', '23/2/2007',
#        '23/3/2007', '23/4/2007', '23/5/2007', '23/6/2007', '23/7/2007',
#        '23/8/2007', '23/9/2007', '24/1/2007', '24/10/2007', '24/11/2007',
#        '24/12/2007', '24/2/2007', '24/3/2007', '24/4/2007', '24/5/2007',
#        '24/6/2007', '24/7/2007', '24/8/2007', '24/9/2007', '25/1/2007',
#        '25/10/2007', '25/11/2007', '25/12/2007', '25/2/2007', '25/3/2007',
#        '25/4/2007', '25/5/2007', '25/6/2007', '25/7/2007', '25/8/2007',
#        '25/9/2007', '26/1/2007', '26/10/2007', '26/11/2007', '26/12/2007',
#        '26/2/2007', '26/3/2007', '26/4/2007', '26/5/2007', '26/6/2007',
#        '26/7/2007', '26/8/2007', '26/9/2007', '27/1/2007', '27/10/2007',
#        '27/11/2007', '27/12/2007', '27/2/2007', '27/3/2007', '27/4/2007',
#        '27/5/2007', '27/6/2007', '27/7/2007', '27/8/2007', '27/9/2007',
#        '28/1/2007', '28/10/2007', '28/11/2007', '28/12/2007', '28/2/2007',
#        '28/3/2007', '28/4/2007', '28/5/2007', '28/6/2007', '28/7/2007',
#        '28/8/2007', '28/9/2007', '29/1/2007', '29/10/2007', '29/11/2007',
#        '29/12/2007', '29/3/2007', '29/4/2007', '29/5/2007', '29/6/2007',
#        '29/7/2007', '29/8/2007', '29/9/2007', '3/1/2007', '3/10/2007',
#        '3/11/2007', '3/12/2007', '3/2/2007', '3/3/2007', '3/4/2007',
#        '3/5/2007', '3/6/2007', '3/7/2007', '3/8/2007', '3/9/2007',
#        '30/1/2007', '30/10/2007', '30/11/2007', '30/12/2007', '30/3/2007',
#        '30/4/2007', '30/5/2007', '30/6/2007', '30/7/2007', '30/8/2007',
#        '30/9/2007', '31/1/2007', '31/10/2007', '31/12/2007', '31/3/2007',
#        '31/5/2007', '31/7/2007', '31/8/2007', '4/1/2007', '4/10/2007',
#        '4/11/2007', '4/12/2007', '4/2/2007', '4/3/2007', '4/4/2007',
#        '4/5/2007', '4/6/2007', '4/7/2007', '4/8/2007', '4/9/2007',
#        '5/1/2007', '5/10/2007', '5/11/2007', '5/12/2007', '5/2/2007',
#        '5/3/2007', '5/4/2007', '5/5/2007', '5/6/2007', '5/7/2007',
#        '5/8/2007', '5/9/2007', '6/1/2007', '6/10/2007', '6/11/2007',
#        '6/12/2007', '6/2/2007', '6/3/2007', '6/4/2007', '6/5/2007',
#        '6/6/2007', '6/7/2007', '6/8/2007', '6/9/2007', '7/1/2007',
#        '7/10/2007', '7/11/2007', '7/12/2007', '7/2/2007', '7/3/2007',
#        '7/4/2007', '7/5/2007', '7/6/2007', '7/7/2007', '7/8/2007',
#        '7/9/2007', '8/1/2007', '8/10/2007', '8/11/2007', '8/12/2007',
#        '8/2/2007', '8/3/2007', '8/4/2007', '8/5/2007', '8/6/2007',
#        '8/7/2007', '8/8/2007', '8/9/2007', '9/1/2007', '9/10/2007',
#        '9/11/2007', '9/12/2007', '9/2/2007', '9/3/2007', '9/4/2007',
#        '9/5/2007', '9/6/2007', '9/7/2007', '9/8/2007', '9/9/2007'],
#       dtype=object)

# %%
xx = rs.iloc[19835:19838,:]
xx
# Out:
#       g_active_power g_reactive_power  voltage global_intensity sub_1_kitchen  \
# 19835          3.222            0.312  233.300           13.800         0.000
# 19836              ?                ?        ?                ?             ?
# 19837          3.204            0.202  232.700           13.800         0.000
#
#       sub_2_laundry  sub_3_wh_ac           full_time
# 19835         0.000         16.0 2007-01-14 18:35:00
# 19836             ?          NaN 2007-01-14 18:36:00
# 19837         0.000         17.0 2007-01-14 18:37:00

# %%
xx.dropna(how='any')
# Out:
#       g_active_power g_reactive_power  voltage global_intensity sub_1_kitchen  \
# 19835          3.222            0.312  233.300           13.800         0.000
# 19837          3.204            0.202  232.700           13.800         0.000
#
#       sub_2_laundry  sub_3_wh_ac           full_time
# 19835         0.000         16.0 2007-01-14 18:35:00
# 19837         0.000         17.0 2007-01-14 18:37:00

# %%
rsdroped = rs.dropna(how = 'any')

# %%
rsdroped
# Out:
#        g_active_power g_reactive_power  voltage global_intensity  \
# 0               2.580            0.136  241.970           10.600
# 1               2.552            0.100  241.750           10.400
# 2               2.550            0.100  241.640           10.400
# 3               2.550            0.100  241.710           10.400
# 4               2.554            0.100  241.980           10.400
# ...               ...              ...      ...              ...
# 525595          1.746            0.204   242.41              7.2
# 525596          1.732             0.21   242.42              7.2
# 525597          1.732             0.21    242.5              7.2
# 525598          1.684            0.144   242.18                7
# 525599          1.628            0.072   241.79              6.6
#
#        sub_1_kitchen sub_2_laundry  sub_3_wh_ac           full_time
# 0              0.000         0.000          0.0 2007-01-01 00:00:00
# 1              0.000         0.000          0.0 2007-01-01 00:01:00
# 2              0.000         0.000          0.0 2007-01-01 00:02:00
# 3              0.000         0.000          0.0 2007-01-01 00:03:00
# 4              0.000         0.000          0.0 2007-01-01 00:04:00
# ...              ...           ...          ...                 ...
# 525595             0             0         18.0 2007-12-31 23:55:00
# 525596             0             0         18.0 2007-12-31 23:56:00
# 525597             0             0         18.0 2007-12-31 23:57:00
# 525598             0             0         18.0 2007-12-31 23:58:00
# 525599             0             0         18.0 2007-12-31 23:59:00
#
# [521669 rows x 8 columns]

# %%
rsdroped.iloc[:,:-1] = rsdroped.iloc[:,:-1].apply(pd.to_numeric)
rsdroped
# Out:
# C:\Users\lu\Anaconda3\envs\tf2\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#         g_active_power  g_reactive_power  voltage  global_intensity  \
# 0                2.580             0.136   241.97              10.6
# 1                2.552             0.100   241.75              10.4
# 2                2.550             0.100   241.64              10.4
# 3                2.550             0.100   241.71              10.4
# 4                2.554             0.100   241.98              10.4
# ...                ...               ...      ...               ...
# 525595           1.746             0.204   242.41               7.2
# 525596           1.732             0.210   242.42               7.2
# 525597           1.732             0.210   242.50               7.2
# 525598           1.684             0.144   242.18               7.0
# 525599           1.628             0.072   241.79               6.6
#
#         sub_1_kitchen  sub_2_laundry  sub_3_wh_ac           full_time
# 0                 0.0            0.0          0.0 2007-01-01 00:00:00
# 1                 0.0            0.0          0.0 2007-01-01 00:01:00
# 2                 0.0            0.0          0.0 2007-01-01 00:02:00
# 3                 0.0            0.0          0.0 2007-01-01 00:03:00
# 4                 0.0            0.0          0.0 2007-01-01 00:04:00
# ...               ...            ...          ...                 ...
# 525595            0.0            0.0         18.0 2007-12-31 23:55:00
# 525596            0.0            0.0         18.0 2007-12-31 23:56:00
# 525597            0.0            0.0         18.0 2007-12-31 23:57:00
# 525598            0.0            0.0         18.0 2007-12-31 23:58:00
# 525599            0.0            0.0         18.0 2007-12-31 23:59:00
#
# [521669 rows x 8 columns]

# %%
rsdroped.resample('2H',on='full_time').mean()
# Out:
#                      g_active_power  g_reactive_power     voltage  \
# full_time
# 2007-01-01 00:00:00        2.537017          0.092217  241.228917
# 2007-01-01 02:00:00        2.562000          0.098383  243.232917
# 2007-01-01 04:00:00        2.475983          0.094917  242.402417
# 2007-01-01 06:00:00        2.451500          0.096500  240.768000
# 2007-01-01 08:00:00        2.793933          0.072850  240.461000
# ...                             ...               ...         ...
# 2007-12-31 14:00:00        1.574450          0.123467  244.531083
# 2007-12-31 16:00:00        2.603000          0.082467  239.726583
# 2007-12-31 18:00:00        3.232233          0.064600  235.260750
# 2007-12-31 20:00:00        1.753383          0.071133  237.973167
# 2007-12-31 22:00:00        1.615183          0.072800  240.864667
#
#                      global_intensity  sub_1_kitchen  sub_2_laundry  \
# full_time
# 2007-01-01 00:00:00         10.486667            0.0       0.291667
# 2007-01-01 02:00:00         10.470000            0.0       0.300000
# 2007-01-01 04:00:00         10.130000            0.0       0.291667
# 2007-01-01 06:00:00         10.111667            0.0       0.275000
# 2007-01-01 08:00:00         11.550000            0.0       0.025000
# ...                               ...            ...            ...
# 2007-12-31 14:00:00          6.440000            0.0       0.516667
# 2007-12-31 16:00:00         10.846667            0.0       0.241667
# 2007-12-31 18:00:00         13.701667            0.0       0.241667
# 2007-12-31 20:00:00          7.301667            0.0       0.233333
# 2007-12-31 22:00:00          6.646667            0.0       0.233333
#
#                      sub_3_wh_ac
# full_time
# 2007-01-01 00:00:00     0.000000
# 2007-01-01 02:00:00     0.000000
# 2007-01-01 04:00:00     0.000000
# 2007-01-01 06:00:00     0.000000
# 2007-01-01 08:00:00     6.016667
# ...                          ...
# 2007-12-31 14:00:00    18.325000
# 2007-12-31 16:00:00    17.633333
# 2007-12-31 18:00:00    17.000000
# 2007-12-31 20:00:00    17.383333
# 2007-12-31 22:00:00    17.791667
#
# [4380 rows x 7 columns]
